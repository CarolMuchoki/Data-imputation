# %%
import pandas as pd
import matplotlib.pyplot as plt

#transformers to impute missing data
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

#to split the dataset
from sklearn.model_selection import train_test_split

# %%
raw_data4 = pd.read_excel('copySTRB_Met_.xlsx')
df = raw_data4.copy()
df.head()
# Out:
#      Subject Repeat Visit   BMI Ethnicity Sex  Age    Treat   Time      TG  \
# 0  STRB_5102      Y  PPD1  36.4       CAU   F   56  Control    0.0  155.16
# 1  STRB_5102      Y  PPD1  36.4       CAU   F   56  Control   30.0  150.12
# 2  STRB_5102      Y  PPD1  36.4       CAU   F   56  Control   60.0  186.09
# 3  STRB_5102      Y  PPD1  36.4       CAU   F   56  Control   90.0  192.25
# 4  STRB_5102      Y  PPD1  36.4       CAU   F   56  Control  120.0  163.68
#
#    ...  b_Ins   N_Ins       HOMA  b_HOMA  HOMACat  HOMAC2  IR  RatioInsGlc  \
# 0  ...  8.079   0.000   1.910235    1.91        N       N   N     0.084367
# 1  ...  8.079  65.004  17.776312    1.91        N       N   N     0.741884
# 2  ...  8.079  50.963  11.935231    1.91        N       N   N     0.721168
# 3  ...  8.079  23.403   5.490305    1.91        N       N   N     0.445731
# 4  ...  8.079  23.213   5.330457    1.91        N       N   N     0.453573
#
#    RatioGlcIns  MetS
# 0    11.852952     N
# 1     1.347919     N
# 2     1.386640     N
# 3     2.243504     N
# 4     2.204717     N
#
# [5 rows x 29 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop("Time", axis=1), df["Time"], test_size = 0.3, random_state = 0, )

X_train.shape, X_test.shape
# Out:
# ((604, 28), (260, 28))

# %%
X_train.isnull().mean()
# Out:
# Subject        0.000000
# Repeat         0.000000
# Visit          0.000000
# BMI            0.000000
# Ethnicity      0.000000
# Sex            0.000000
# Age            0.000000
# Treat          0.000000
# TG             0.023179
# b_TG           0.019868
# N_TG           0.023179
# Chol           0.023179
# b_Chol         0.019868
# N_Chol         0.023179
# Glc            0.023179
# b_Glc          0.019868
# N_Glc          0.023179
# Insulin        0.026490
# b_Ins          0.043046
# N_Ins          0.048013
# HOMA           0.026490
# b_HOMA         0.043046
# HOMACat        0.031457
# HOMAC2         0.019868
# IR             0.000000
# RatioInsGlc    0.026490
# RatioGlcIns    0.026490
# MetS           0.019868
# dtype: float64

# %%
imputer = SimpleImputer(strategy = 'most_frequent')
imputer.fit (X_train)
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
imputer.statistics_
# Out:
# array(['STRB_5122', 'N', 'PPD1', 36.4, 'AA', 'F', 27, 'SD2', 83.93, 40.56,
#        0.0, 144.13, 121.21, 0.0, 80.88, 99.91, 0.0, 19.418, 7.2617, 0.0,
#        0.2714348642, 1.902106074, 'Y', 'Y', 'N', 0.01287257019,
#        0.4083155429, 'N'], dtype=object)

# %%
X_train.mode()
# Out:
#        Subject Repeat Visit   BMI Ethnicity  Sex   Age Treat      TG    b_TG  \
# 0    STRB_5122      N  PPD1  36.4        AA    F  27.0   SD2   83.93   40.56
# 1    STRB_5123    NaN   NaN   NaN       NaN  NaN   NaN   NaN   87.72  100.24
# 2    STRB_5129    NaN   NaN   NaN       NaN  NaN   NaN   NaN  101.61     NaN
# 3          NaN    NaN   NaN   NaN       NaN  NaN   NaN   NaN  101.91     NaN
# 4          NaN    NaN   NaN   NaN       NaN  NaN   NaN   NaN  103.15     NaN
# ..         ...    ...   ...   ...       ...  ...   ...   ...     ...     ...
# 583        NaN    NaN   NaN   NaN       NaN  NaN   NaN   NaN     NaN     NaN
# 584        NaN    NaN   NaN   NaN       NaN  NaN   NaN   NaN     NaN     NaN
# 585        NaN    NaN   NaN   NaN       NaN  NaN   NaN   NaN     NaN     NaN
# 586        NaN    NaN   NaN   NaN       NaN  NaN   NaN   NaN     NaN     NaN
# 587        NaN    NaN   NaN   NaN       NaN  NaN   NaN   NaN     NaN     NaN
#
#      ...    b_Ins  N_Ins        HOMA    b_HOMA  HOMACat  HOMAC2   IR  \
# 0    ...   7.2617    0.0    0.271435  1.902106        Y       Y    N
# 1    ...  12.0375    NaN    0.272541  3.089497      NaN     NaN  NaN
# 2    ...      NaN    NaN    0.337416       NaN      NaN     NaN  NaN
# 3    ...      NaN    NaN    0.423482       NaN      NaN     NaN  NaN
# 4    ...      NaN    NaN    0.424846       NaN      NaN     NaN  NaN
# ..   ...      ...    ...         ...       ...      ...     ...  ...
# 583  ...      NaN    NaN   88.815412       NaN      NaN     NaN  NaN
# 584  ...      NaN    NaN   90.635422       NaN      NaN     NaN  NaN
# 585  ...      NaN    NaN   93.305375       NaN      NaN     NaN  NaN
# 586  ...      NaN    NaN   96.961045       NaN      NaN     NaN  NaN
# 587  ...      NaN    NaN  100.133863       NaN      NaN     NaN  NaN
#
#      RatioInsGlc  RatioGlcIns  MetS
# 0       0.012873     0.408316     N
# 1       0.013584     0.413439   NaN
# 2       0.015257     0.476165   NaN
# 3       0.015472     0.484840   NaN
# 4       0.017041     0.485299   NaN
# ..           ...          ...   ...
# 583     2.060584    58.682831   NaN
# 584     2.062537    64.633854   NaN
# 585     2.100112    65.544258   NaN
# 586     2.418736    73.617021   NaN
# 587     2.449086    77.684564   NaN
#
# [588 rows x 28 columns]

# %%
X_train = imputer.transform(X_train)
X_test = imputer.transform(X_test)
X_train
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([['STRB_5120', 'N', 'PPD1', ..., 0.08465411559, 11.81277476, 'Y'],
#        ['STRB_5131', 'N', 'PPD1', ..., 0.1948190876, 5.13296727, 'N'],
#        ['STRB_5128', 'N', 'PPD2', ..., 0.6901651815, 1.448928498, 'N'],
#        ...,
#        ['STRB_5124', 'N', 'PPD2', ..., 0.1803450327, 5.544926771, 'N'],
#        ['STRB_5122', 'N', 'PPD3', ..., 0.6727945101, 1.486337931, 'N'],
#        ['STRB_5127', 'N', 'PPD1', ..., 0.04272495515, 23.40552486, 'Y']],
#       dtype=object)
